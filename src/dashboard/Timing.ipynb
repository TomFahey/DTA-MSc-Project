# %%
# %softreset
# Out:
# Keyboard Interrupt

# %%
from main import *
# Out:
# No connection to CiruitPython VM: failed to enter raw repl with /dev/ttyACM0

# %%
main()
# Out:
# No connection to CiruitPython VM: failed to enter raw repl with /dev/ttyACM0

# %%
n = 0
timings = []
while (n < 1000):
    lastTimeStamp = time.monotonic_ns()
    timings.append(timeit_ms(lambda x: x.run(), thisSupervisor))
    thisSupervisor.wait(lastTimeStamp)
    n += 1

# %%
print(n)
# Out:
# 1000

# %%
print(max(timings))
# Out:
# 53.711

# %%
from ulab import numpy as np

# %%
print((np.array(timings)[(np.array(timings)>np.mean(timings)+np.std(timings))]).tolist())
# Out:
# [38.086, 45.898, 40.039, 41.016, 40.039, 41.016, 41.016, 45.898, 40.039, 41.016, 40.039, 43.945, 39.062, 17.578, 35.156, 18.555, 17.578, 18.555, 18.555, 17.578, 35.156, 17.578, 17.578, 34.18, 53.711, 40.039]

# %%
print(timings)
# Out:
# [38.086, 45.898, 40.039, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 41.016, 40.039, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 41.016, 41.016, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 45.898, 40.039, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 9.766, 41.016, 40.039, 43.945, 39.062, 9.766, 9.766, 8.789, 9.766, 8.789, 8.789, 8.789, 9.766, 9.766, 8.789, 8.789, 8.789, 9.766, 8.789, 9.766, 8.789, 8.789, 8.789, 8.789, 8.789, 8.789, 8.789, 9.766, 8.789, 8.789, 9.766, 8.789, 8.789, 8.789, 9.766, 8.789, 9.766, 9.766, 9.766, 9.76
# ...

# %%
while True:
    lastTimeStamp = time.monotonic_ns()
    thisSupervisor.run()
    thisSupervisor.wait(lastTimeStamp)
# Out:
# Keyboard Interrupt
