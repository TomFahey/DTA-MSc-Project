# %%
import os
import sys

ROOT_DIR = os.path.abspath('../')
WEBAPP_PATH = ROOT_DIR + '/src/dashboard/'
sys.path.insert(0, WEBAPP_PATH)

from webapp.programme import *
display(app)
# Out:
# ProgrammeTab(children=(StageTab(children=(ControlSlider(value=23, continuous_update=False, layout=Layout(width…

# %%
import os
import sys

ROOT_DIR = os.path.abspath('../')
WEBAPP_PATH = ROOT_DIR + '/src/dashboard/'
sys.path.insert(0, WEBAPP_PATH)

from webapp.programme import StageTab
display(StageTab())
# Out:
# StageTab(children=(ControlSlider(value=23, continuous_update=False, layout=Layout(width='100%'), max=200), Con…

# %%
import os
import sys

ROOT_DIR = os.path.abspath('../')
WEBAPP_PATH = ROOT_DIR + '/src/dashboard/'
sys.path.insert(0, WEBAPP_PATH)

from webapp.programme import ControlSlider
display(ControlSlider(stage={'R': 100}, target='R'))
# Out:
# ControlSlider(value=22, continuous_update=False, layout=Layout(width='100%'), max=200)
