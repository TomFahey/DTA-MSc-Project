# %%
import os
import sys

ROOT_DIR = os.path.abspath('../')
WEBAPP_PATH = ROOT_DIR + '/src/dashboard/'
sys.path.insert(0, WEBAPP_PATH)

from webapp.settings import *
display(app)
# Out:
# ConfigTab(children=(ControlSlider(value=35.0, continuous_update=False, layout=Layout(width='62.5%'), step=0.5)…

# %%
import os
import sys

ROOT_DIR = os.path.abspath('../')
WEBAPP_PATH = ROOT_DIR + '/src/dashboard/'
sys.path.insert(0, WEBAPP_PATH)

from webapp.settings import ControlSlider
from webapp.shared import appState

app = ControlSlider(appState.config, 'KP')
display(app)
# Out:
# ControlSlider(value=1.0, continuous_update=False, layout=Layout(width='62.5%'), step=0.05)

# %%
display(app)
# Out:
# ControlSlider(value=1.0, continuous_update=False, layout=Layout(width='62.5%'), step=0.05)
